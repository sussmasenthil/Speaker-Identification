# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Audio_features01.csv')
df = pd.DataFrame(df)
df.head()
pred = df.drop('ID',axis = 1)
pred.head()
# Out:
#      max_pitch  avg_pitch     var_pitch      harmonic  harmonic_var  \
# 0  3997.841064  42.346413   96089.29688 -1.560000e-06      0.000202
# 1  3990.921631  24.817791   54618.11719 -1.270000e-07      0.000372
# 2  3998.479736  42.045082   96594.42188  2.510000e-07      0.000216
# 3  3999.575439  44.815517  102965.95310  2.490000e-06      0.000615
# 4  3996.976074  33.027214   70115.64063 -4.280000e-07      0.000500
#
#    percussive  percussive_var  Chroma_cens  Chroma_cens_var  chroma_stft_mean  \
# 0   -0.000006        0.000108     0.242919         0.024324          0.339705
# 1   -0.000011        0.000095     0.230322         0.030285          0.285754
# 2   -0.000007        0.000082     0.236287         0.027502          0.358004
# 3    0.000003        0.000221     0.253536         0.019053          0.387897
# 4   -0.000011        0.000292     0.247803         0.021927          0.347066
#
#     ...    tonnetz_var  poly_features_mean  poly_features_var  spec_bw_mean  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
ss=StandardScaler()
enc = LabelEncoder()
target = enc.fit_transform(df.ID)
pred.Gender = enc.fit_transform(df.Gender)
Scaled_x = pd.DataFrame(ss.fit_transform(pred))

# %%
pca = PCA()
pca.fit_transform(Scaled_x)
pca.explained_variance_
# Out:
# array([7.43140593e+00, 6.46525292e+00, 4.93857682e+00, 2.66054236e+00,
#        1.95514160e+00, 1.42293838e+00, 1.32851248e+00, 1.18259843e+00,
#        1.04010345e+00, 9.71622760e-01, 9.62084255e-01, 8.67225969e-01,
#        7.56481647e-01, 6.15287096e-01, 5.66359991e-01, 4.66012503e-01,
#        4.04009535e-01, 3.23911381e-01, 3.17616430e-01, 2.64425473e-01,
#        2.14439846e-01, 1.81027720e-01, 1.61525379e-01, 1.28042142e-01,
#        1.08735827e-01, 8.82036090e-02, 6.23217674e-02, 5.27648270e-02,
#        2.35465243e-02, 1.81803418e-02, 1.05016415e-02, 6.60315523e-03,
#        5.92816355e-03, 3.59126143e-03, 1.35952385e-03, 5.08027822e-04])

# %%
plt.semilogy(pca.explained_variance_,'--o')
plt.title('Scree Plot')
# Out:
# Text(0.5,1,'Scree Plot')
